# %% [markdown]
# <a href="https://colab.research.google.com/github/shahchayan9/Pycaret-low-code-tasks/blob/main/Gradio_Demo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret[mlops] pandas

# %%
from pycaret.datasets import get_data
from pycaret.regression import *
dataset = get_data('energy')
# Out:
#    Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 0                  0.98         514.5      294.0     110.25             7.0
# 1                  0.98         514.5      294.0     110.25             7.0
# 2                  0.98         514.5      294.0     110.25             7.0
# 3                  0.98         514.5      294.0     110.25             7.0
# 4                  0.90         563.5      318.5     122.50             7.0
#
#    Orientation  Glazing Area  Glazing Area Distribution  Heating Load  \
# 0            2           0.0                          0         15.55
# 1            3           0.0                          0         15.55
# 2            4           0.0                          0         15.55
# 3            5           0.0                          0         15.55
# 4            2           0.0                          0         20.84
#
#    Cooling Load
# 0         21.33
# 1         21.33
# 2         21.33
# 3         21.33
# ...

# %%
test = setup(dataset, target='Glazing Area', session_id=123)
# Out:
# <style type="text/css">
# #T_3346f_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3346f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3346f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3346f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3346f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3346f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3346f_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_3346f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3346f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3346f_row1_col1" class="data row1 col1" >Glazing Area</td>
#     </tr>
#     <tr>
#       <th id="T_3346f_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_2ccf8_row10_col0, #T_2ccf8_row10_col1, #T_2ccf8_row10_col2, #T_2ccf8_row10_col3, #T_2ccf8_row10_col4, #T_2ccf8_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_2ccf8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ccf8_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_2ccf8_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_2ccf8_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_2ccf8_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_2ccf8_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_2ccf8_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
create_app(dt)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://52360248cc03cc18db.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://52360248cc03cc18db.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
